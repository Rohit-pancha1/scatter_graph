# %%
import pandas as pd
a= pd.read_csv('p.csv')
x= a['Name ']
y=a['Marks']
a.head()
# Out:
#      Name   Marks
# 0    Rohit     89
# 1   Keerti     56
# 2  Prinshi     84
# 3    Mohit     75
# 4   Mukesh     94

# %%
x
# Out:
# 0      Rohit
# 1     Keerti
# 2    Prinshi
# 3      Mohit
# 4     Mukesh
# 5       Rani
# 6     Roshni
# Name: Name , dtype: object

# %%
y
# Out:
# 0    89
# 1    56
# 2    84
# 3    75
# 4    94
# 5    86
# 6    81
# Name: Marks, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.boxplot(a['Marks'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14bf0ccf050>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14bf0cd8910>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14bf0c9dd90>],
#  'medians': [<matplotlib.lines.Line2D at 0x14bf0cd9fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14beeb11cd0>],
#  'means': []}

# %%
plt.boxplot([4,5,4,7,8,6,12],showcaps=False,showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14bf3453490>,
# ...
#  'caps': [],
#  'boxes': [<matplotlib.lines.Line2D at 0x14bf3452810>],
#  'medians': [<matplotlib.lines.Line2D at 0x14bf3460d10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14bf340ed50>],
#  'means': [<matplotlib.lines.Line2D at 0x14bf34616d0>]}

# %%
plt.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14bf3602510>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14bf3603ad0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14bf36018d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x14bf36150d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14bf3615ad0>],
#  'means': []}

# %%
plt.violinplot([4,5,3,7,6,4,12],vert=False, showmeans=True, showmedians= True,)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x14bf4d91c10>],
#  'cmeans': <matplotlib.collections.LineCollection at 0x14bf4d92d90>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x14bf4d48810>,
#  'cmins': <matplotlib.collections.LineCollection at 0x14bf4d919d0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x14bf4d555d0>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x14bf4da2ed0>}
